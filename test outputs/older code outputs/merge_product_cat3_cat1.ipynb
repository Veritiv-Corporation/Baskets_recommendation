# %%
import pandas as pd
product_result=pd.read_csv('results_weighted_4_withprop.csv')
# Out:
# C:\Users\liyenga\AppData\Local\Temp\ipykernel_18228\3552650769.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
product_result_100_freq=pd.read_csv('result_with_freq_cat_100_10.csv')

# %%
cat3_cat3_cooccur=pd.read_csv('cat3_cat3_cooccurance.csv')

# %%
cat1_cat1_cooccur=pd.read_csv('cat1_cat1_cooccurance.csv')

# %%
# Load items 
df = pd.read_excel('digital_commerce_items.xlsx', usecols=['Item Number', 'Item Description'])
print(f">> Loaded {len(df)} e-commerce items and their descriptions")
# Out:
# >> Loaded 3774 e-commerce items and their descriptions

# %%
df.rename(columns={'Item Number': 'item_cde','Item Description':'description'}, 
          inplace=True)
print(f">> Renamed the columns to {df.columns.tolist()}")
# Out:
# >> Renamed the columns to ['item_cde', 'description']

# %%
product_result_100_freq['Level'] = 'product'

# %%
# Merge df with product_result_100_freq to find items in df that are not in product_result_100_freq
merged = pd.merge(df, product_result_100_freq, on='item_cde', how='left', indicator=True)

# Filter out the rows present only in df
not_in_product_result_100_freq = merged[merged['_merge'] == 'left_only']

# Add the filtered rows to product_result_100_freq, including 'item_cde' and corresponding 'description'
new_items = not_in_product_result_100_freq[['item_cde', 'description']]
new_items.rename(columns={'description': 'item description'}, inplace=True)  # Rename the 'description' column to 'item description'
product_result_100_freq = pd.concat([product_result_100_freq, new_items], ignore_index=True)
# Out:
# C:\Users\liyenga\AppData\Local\Temp\ipykernel_18228\3244891855.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_items.rename(columns={'description': 'item description'}, inplace=True)  # Rename the 'description' column to 'item description'

# %%
cat_results=pd.read_csv('cat3_result_df_update_1.csv')
cat_results['item_cde'] = cat_results['item_cde'].astype(int)

# %%
item_category_map = dict(zip(cat_results['item_cde'], cat_results['Category']))

# %%
cat3_reco1 = dict(zip(cat3_cat3_cooccur['Unnamed: 0'], cat3_cat3_cooccur['Recommendation 1']))
cat3_reco2 = dict(zip(cat3_cat3_cooccur['Unnamed: 0'], cat3_cat3_cooccur['Recommendation 2']))
cat3_reco3 = dict(zip(cat3_cat3_cooccur['Unnamed: 0'], cat3_cat3_cooccur['Recommendation 3']))
cat3_reco4 = dict(zip(cat3_cat3_cooccur['Unnamed: 0'], cat3_cat3_cooccur['Recommendation 4']))
cat3_reco5 = dict(zip(cat3_cat3_cooccur['Unnamed: 0'], cat3_cat3_cooccur['Recommendation 5']))

# %%
cat3_top_5_items=pd.read_excel('top_5_items_catwise_2.xlsx')

# %%
type(cat3_top_items_map['Ancillary Packaging.Absorbents.MISSING'])
# Out:
# str

# %%
import ast

cat3_top_5_items['item_cde'] = cat3_top_5_items['item_cde'].apply(ast.literal_eval)

# %%
cat3_top_items_map = dict(zip(cat3_top_5_items['cat'], cat3_top_5_items['item_cde']))

# %%
# Initialize an empty dictionary to store the mapping from 'item_cde' to recommended 'item_cde'
item_to_recommended1_item_map = {}

# Iterate over each 'item_cde' in the item_category_map
for item_cde, category in item_category_map.items():
    # Check if the category has a recommendation in cat3_reco1
    if category in cat3_reco1:
        # Get the recommended 'item_cde' based on the category
        recommended_category = cat3_reco1[category]
        
        # Check if the recommended category has a corresponding 'item_cde' in cat3_top_items_map
        if recommended_category in cat3_top_items_map:
            # Get the recommended 'item_cde' based on the recommended category
            recommended_item_cde = cat3_top_items_map[recommended_category]
            
            # Add the mapping from 'item_cde' to recommended 'item_cde' to the map
            item_to_recommended1_item_map[item_cde] = recommended_item_cde

# %%
item_to_recommended1_item_map
# Out:
# {10723330: ['11095923', '10728683', '10728685', '10728306', '10728692'],
#  20035596: ['10421097', '10049675', '10546160', '10546164', '10445161'],
#  10911764: ['10911713', '10735848', '10911699', '10735864', '10735866'],
#  10115095: ['10058192', '10036272', '10036273', '10036270', '10041298'],
#  10412058: ['10343507', '10473204', '10528401', '10447705', '10042857'],
#  11106343: ['11095923', '10728683', '10728685', '10728306', '10728692'],
#  10518585: ['10343507', '10473204', '10528401', '10447705', '10042857'],
#  20060226: ['11023420', '10099538', '20039761', '10805274', '10805283'],
#  20031557: ['10421097', '10049675', '10546160', '10546164', '10445161'],
#  10969158: ['10555041', '11065986', '10752405', '10919698', '11105437'],
#  10698824: ['10343507', '10473204', '10528401', '10447705', '10042857'],
#  10911823: ['10911713', '10735848', '10911699', '10735864', '10735866'],
#  10788944: ['10058192', '10036272', '10036273', '10036270', '10041298'],
# ...

# %%
# Initialize an empty dictionary to store the mapping from 'item_cde' to recommended 'item_cde'
item_to_recommended2_item_map = {}

# Iterate over each 'item_cde' in the item_category_map
for item_cde, category in item_category_map.items():
    # Check if the category has a recommendation in cat3_reco1
    if category in cat3_reco2:
        # Get the recommended 'item_cde' based on the category
        recommended_category = cat3_reco2[category]
        
        # Check if the recommended category has a corresponding 'item_cde' in cat3_top_items_map
        if recommended_category in cat3_top_items_map:
            # Get the recommended 'item_cde' based on the recommended category
            recommended_item_cde = cat3_top_items_map[recommended_category]
            
            # Add the mapping from 'item_cde' to recommended 'item_cde' to the map
            item_to_recommended2_item_map[item_cde] = recommended_item_cde

# %%
# Initialize an empty dictionary to store the mapping from 'item_cde' to recommended 'item_cde'
item_to_recommended3_item_map = {}

# Iterate over each 'item_cde' in the item_category_map
for item_cde, category in item_category_map.items():
    # Check if the category has a recommendation in cat3_reco1
    if category in cat3_reco3:
        # Get the recommended 'item_cde' based on the category
        recommended_category = cat3_reco3[category]
        
        # Check if the recommended category has a corresponding 'item_cde' in cat3_top_items_map
        if recommended_category in cat3_top_items_map:
            # Get the recommended 'item_cde' based on the recommended category
            recommended_item_cde = cat3_top_items_map[recommended_category]
            
            # Add the mapping from 'item_cde' to recommended 'item_cde' to the map
            item_to_recommended3_item_map[item_cde] = recommended_item_cde

# %%
# Initialize an empty dictionary to store the mapping from 'item_cde' to recommended 'item_cde'
item_to_recommended4_item_map = {}

# Iterate over each 'item_cde' in the item_category_map
for item_cde, category in item_category_map.items():
    # Check if the category has a recommendation in cat3_reco1
    if category in cat3_reco4:
        # Get the recommended 'item_cde' based on the category
        recommended_category = cat3_reco4[category]
        
        # Check if the recommended category has a corresponding 'item_cde' in cat3_top_items_map
        if recommended_category in cat3_top_items_map:
            # Get the recommended 'item_cde' based on the recommended category
            recommended_item_cde = cat3_top_items_map[recommended_category]
            
            # Add the mapping from 'item_cde' to recommended 'item_cde' to the map
            item_to_recommended4_item_map[item_cde] = recommended_item_cde

# %%
# Initialize an empty dictionary to store the mapping from 'item_cde' to recommended 'item_cde'
item_to_recommended5_item_map = {}

# Iterate over each 'item_cde' in the item_category_map
for item_cde, category in item_category_map.items():
    # Check if the category has a recommendation in cat3_reco1
    if category in cat3_reco5:
        # Get the recommended 'item_cde' based on the category
        recommended_category = cat3_reco5[category]
        
        # Check if the recommended category has a corresponding 'item_cde' in cat3_top_items_map
        if recommended_category in cat3_top_items_map:
            # Get the recommended 'item_cde' based on the recommended category
            recommended_item_cde = cat3_top_items_map[recommended_category]
            
            # Add the mapping from 'item_cde' to recommended 'item_cde' to the map
            item_to_recommended5_item_map[item_cde] = recommended_item_cde

# %%
item_to_recommended5_item_map
# Out:
# {10723330: ['10958533', '10727931', '10727941', '11015991', '20046533'],
#  20035596: ['10169745', '10049812', '10574148', '10093052', '10050919'],
#  10911764: ['10802527', '10298253', '10301632', '20092466', '10302459'],
#  10115095: ['10958533', '10727931', '10727941', '11015991', '20046533'],
#  10412058: ['10834379', '11136832', '11131131', '10788363', '10987880'],
#  11106343: ['10098323', '10396065', '20037330', '10366590', '10389081'],
#  10518585: ['10847888', '10847885', '10847897', '10474083', '11126587'],
#  20060226: ['10710453', '10741667', '10082155', '10396076', '10598675'],
#  20031557: ['20030014', '10112299', '11052578', '11052530', '11052562'],
#  10969158: ['10287922', '10805851', '11119005', '10778646', '10249506'],
#  10698824: ['10847888', '10847885', '10847897', '10474083', '11126587'],
#  10911823: ['10802527', '10298253', '10301632', '20092466', '10302459'],
#  10788944: ['10802527', '10298253', '10301632', '20092466', '10302459'],
# ...

# %%
# Convert item_to_recommended_item_map to a DataFrame
df_1 = pd.DataFrame(list(item_to_recommended1_item_map.items()), columns=['item_cde', 'recommended_item_cde_1'])

# Convert item_to_recommended_item_map_2 to a DataFrame
df_2 = pd.DataFrame(list(item_to_recommended2_item_map.items()), columns=['item_cde', 'recommended_item_cde_2'])

# Convert item_to_recommended_item_map_3 to a DataFrame
df_3 = pd.DataFrame(list(item_to_recommended3_item_map.items()), columns=['item_cde', 'recommended_item_cde_3'])

# Convert item_to_recommended_item_map_4 to a DataFrame
df_4 = pd.DataFrame(list(item_to_recommended4_item_map.items()), columns=['item_cde', 'recommended_item_cde_4'])

# Convert item_to_recommended_item_map_5 to a DataFrame
df_5 = pd.DataFrame(list(item_to_recommended5_item_map.items()), columns=['item_cde', 'recommended_item_cde_5'])

# Merge the first two DataFrames on 'item_cde'
merged_df = pd.merge(df_1, df_2, on='item_cde', how='outer')

# Merge the result with the third DataFrame on 'item_cde'
merged_df = pd.merge(merged_df, df_3, on='item_cde', how='outer')

# Merge the result with the fourth DataFrame on 'item_cde'
merged_df = pd.merge(merged_df, df_4, on='item_cde', how='outer')

# Merge the result with the fifth DataFrame on 'item_cde'
merged_df = pd.merge(merged_df, df_5, on='item_cde', how='outer')

# Fill missing values with NaN
merged_df.fillna('', inplace=True)

# Display the resulting DataFrame
print(merged_df)
# Out:
#      item_cde                             recommended_item_cde_1  \
# 0    10000633  [20064078, 20064079, 20064080, 20064071, 20064...
# 1    10004037  [10728643, 20002055, 10728668, 20002047, 10728...
# 2    10025406  [11071078, 10853740, 20021543, 11073932, 10843...
# 3    10036510  [10058192, 10036272, 10036273, 10036270, 10041...
# 4    10036645  [10728643, 20002055, 10728668, 20002047, 10728...
# ..        ...                                                ...
# 390  20087263  [10058192, 10036272, 10036273, 10036270, 10041...
# 391  20087278  [10058192, 10036272, 10036273, 10036270, 10041...
# 392  20087302  [10058192, 10036272, 10036273, 10036270, 10041...
# 393  20087303  [10058192, 10036272, 10036273, 10036270, 10041...
# 394  20087304  [10058192, 10036272, 10036273, 10036270, 10041...
#
#                                 recommended_item_cde_2  \
# 0    [20061921, 10814704, 20061927, 20062161, 20061...
# 1    [10058192, 10036272, 10036273, 10036270, 10041...
# ...

# %%
merged_df.to_csv('cat3_level_item_cde_to_reco_2.csv')

# %%
# Apply a lambda function to each column to extract the first element
merged_df['recommended_item_cde_1'] = merged_df['recommended_item_cde_1'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else '')
merged_df['recommended_item_cde_2'] = merged_df['recommended_item_cde_2'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else '')
merged_df['recommended_item_cde_3'] = merged_df['recommended_item_cde_3'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else '')
merged_df['recommended_item_cde_4'] = merged_df['recommended_item_cde_4'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else '')
merged_df['recommended_item_cde_5'] = merged_df['recommended_item_cde_5'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else '')

# Display the resulting DataFrame
print(merged_df)
# Out:
#      item_cde recommended_item_cde_1 recommended_item_cde_2  \
# 0    10000633               20064078               20061921
# 1    10004037               10728643               10058192
# 2    10025406               11071078               10504765
# 3    10036510               10058192               11095923
# 4    10036645               10728643               10058192
# ..        ...                    ...                    ...
# 390  20087263               10058192               10728643
# 391  20087278               10058192               10728643
# 392  20087302               10058192               10728643
# 393  20087303               10058192               10728643
# 394  20087304               10058192               10728643
#
#     recommended_item_cde_3 recommended_item_cde_4 recommended_item_cde_5
# 0                 20064066               11017000               10169745
# 1                 10098323               10169745               10572500
# ...

# %%
# Get the set of 'item_cde' values in merged_df
merged_item_cdes = set(merged_df['item_cde'])

# Get the set of 'item_cde' values in cat_results
cat_results_item_cdes = set(cat_results['item_cde'])

# Find the set difference to get the items in cat_results not in merged_df
items_not_in_merged_df = cat_results_item_cdes - merged_item_cdes

# Convert the result to a list
items_not_in_merged_df = list(items_not_in_merged_df)

# Display the list of items
print(items_not_in_merged_df)
# Out:
# [10961186, 20050754, 20050756, 10880069, 10898537, 20078473, 20034349, 10848206, 11085682, 20041652, 20050748, 11105343]

# %%
cat1_reco1 = dict(zip(cat1_cat1_cooccur['Unnamed: 0'], cat1_cat1_cooccur['Recommendation 1']))
cat1_reco2 = dict(zip(cat1_cat1_cooccur['Unnamed: 0'], cat1_cat1_cooccur['Recommendation 2']))
cat1_reco3 = dict(zip(cat1_cat1_cooccur['Unnamed: 0'], cat1_cat1_cooccur['Recommendation 3']))
cat1_reco4 = dict(zip(cat1_cat1_cooccur['Unnamed: 0'], cat1_cat1_cooccur['Recommendation 4']))
cat1_reco5 = dict(zip(cat1_cat1_cooccur['Unnamed: 0'], cat1_cat1_cooccur['Recommendation 5']))

# %%
cat1_reco2
# Out:
# {'Ancillary Packaging': 'Tapes',
#  'Bags': 'Films',
#  'Can Liners': 'Chemicals',
#  'Chemicals': 'Can Liners',
#  'Coated Freesheet': 'Specialty',
#  'Corrugated': 'Towels, Tissues',
#  'Cushioning': 'Films',
#  'Dispensers': 'Films',
#  'Equipment / Parts': 'Bags',
#  'Films': 'Towels, Tissues',
#  'Folding Carton': 'Food Service',
#  'Food Packaging': 'Food Service',
#  'Food Service': 'Can Liners',
#  'Janitorial Power Equipment': 'Towels, Tissues',
#  'Janitorial Supplies': 'Chemicals',
#  'Labeling / Identification': 'Films',
#  'Mailers': 'Cushioning',
#  'Personal Hygiene': 'Can Liners',
#  'Personal Protection and Safety': 'Can Liners',
#  'Receptacles and Material Handling': 'Chemicals',
#  'Skincare': 'Can Liners',
#  'Specialty': 'Uncoated Freesheet',
#  'Strapping': 'Tapes',
#  'Surface Protection': 'Tapes',
#  'Tapes': 'Cushioning',
#  'Towels, Tissues': 'Skincare',
#  'Uncoated Freesheet': 'Towels, Tissues',
#  'Wide Format': 'Uncoated Freesheet',
# ...

# %%
cat1_top_items=pd.read_excel('cat1_level_top5_items.xlsx')

# %%
cat1_top_items['item_cde'] = cat1_top_items['item_cde'].apply(ast.literal_eval)


cat1_top_items_map = dict(zip(cat1_top_items['cat1'], cat1_top_items['item_cde']))

# %%
# Initialize an empty dictionary to store the mapping from 'item_cde' to recommended 'item_cde'
item_to_recommended1_item_map_cat1 = {}

# Iterate over each 'item_cde' in the item_category_map
for item_cde, category in item_category_map.items():
    # Check if the category has a recommendation in cat3_reco1
    if category in cat1_reco1:
        # Get the recommended 'item_cde' based on the category
        recommended_category = cat1_reco1[category]
        
        # Check if the recommended category has a corresponding 'item_cde' in cat3_top_items_map
        if recommended_category in cat1_top_items_map:
            # Get the recommended 'item_cde' based on the recommended category
            recommended_item_cde = cat1_top_items_map[recommended_category]
            
            # Add the mapping from 'item_cde' to recommended 'item_cde' to the map
            item_to_recommended1_item_map_cat1[item_cde] = recommended_item_cde

# %%
# Initialize an empty dictionary to store the mapping from 'item_cde' to recommended 'item_cde'
item_to_recommended2_item_map_cat1 = {}

# Iterate over each 'item_cde' in the item_category_map
for item_cde, category in item_category_map.items():
    # Check if the category has a recommendation in cat3_reco1
    if category in cat1_reco1:
        # Get the recommended 'item_cde' based on the category
        recommended_category = cat1_reco2[category]
        
        # Check if the recommended category has a corresponding 'item_cde' in cat3_top_items_map
        if recommended_category in cat1_top_items_map:
            # Get the recommended 'item_cde' based on the recommended category
            recommended_item_cde = cat1_top_items_map[recommended_category]
            
            # Add the mapping from 'item_cde' to recommended 'item_cde' to the map
            item_to_recommended2_item_map_cat1[item_cde] = recommended_item_cde

# %%
# Initialize an empty dictionary to store the mapping from 'item_cde' to recommended 'item_cde'
item_to_recommended3_item_map_cat1 = {}

# Iterate over each 'item_cde' in the item_category_map
for item_cde, category in item_category_map.items():
    # Check if the category has a recommendation in cat3_reco1
    if category in cat1_reco1:
        # Get the recommended 'item_cde' based on the category
        recommended_category = cat1_reco3[category]
        
        # Check if the recommended category has a corresponding 'item_cde' in cat3_top_items_map
        if recommended_category in cat1_top_items_map:
            # Get the recommended 'item_cde' based on the recommended category
            recommended_item_cde = cat1_top_items_map[recommended_category]
            
            # Add the mapping from 'item_cde' to recommended 'item_cde' to the map
            item_to_recommended3_item_map_cat1[item_cde] = recommended_item_cde

# %%
# Initialize an empty dictionary to store the mapping from 'item_cde' to recommended 'item_cde'
item_to_recommended4_item_map_cat1 = {}

# Iterate over each 'item_cde' in the item_category_map
for item_cde, category in item_category_map.items():
    # Check if the category has a recommendation in cat3_reco1
    if category in cat1_reco1:
        # Get the recommended 'item_cde' based on the category
        recommended_category = cat1_reco4[category]
        
        # Check if the recommended category has a corresponding 'item_cde' in cat3_top_items_map
        if recommended_category in cat1_top_items_map:
            # Get the recommended 'item_cde' based on the recommended category
            recommended_item_cde = cat1_top_items_map[recommended_category]
            
            # Add the mapping from 'item_cde' to recommended 'item_cde' to the map
            item_to_recommended4_item_map_cat1[item_cde] = recommended_item_cde

# %%
# Initialize an empty dictionary to store the mapping from 'item_cde' to recommended 'item_cde'
item_to_recommended5_item_map_cat1 = {}

# Iterate over each 'item_cde' in the item_category_map
for item_cde, category in item_category_map.items():
    # Check if the category has a recommendation in cat3_reco1
    if category in cat1_reco1:
        # Get the recommended 'item_cde' based on the category
        recommended_category = cat1_reco5[category]
        
        # Check if the recommended category has a corresponding 'item_cde' in cat3_top_items_map
        if recommended_category in cat1_top_items_map:
            # Get the recommended 'item_cde' based on the recommended category
            recommended_item_cde = cat1_top_items_map[recommended_category]
            
            # Add the mapping from 'item_cde' to recommended 'item_cde' to the map
            item_to_recommended5_item_map_cat1[item_cde] = recommended_item_cde

# %%
item_to_recommended1_item_map_cat1
# Out:
# {20034349: ['10169745', '10421097', '10049812', '10574148', '10093052'],
#  11105343: ['10058192', '10036272', '10036273', '10036270', '10041298'],
#  10880069: ['10058192', '10036272', '10036273', '10036270', '10041298'],
#  10898537: ['10058192', '10036272', '10036273', '10036270', '10041298'],
#  11085682: ['10911713', '10735848', '10911699', '10735864', '10735866'],
#  20078473: ['10169745', '10421097', '10049812', '10574148', '10093052'],
#  20041652: ['10169745', '10421097', '10049812', '10574148', '10093052'],
#  10848206: ['10169745', '10421097', '10049812', '10574148', '10093052']}

# %%
# Convert item_to_recommended_item_map to a DataFrame
df_1 = pd.DataFrame(list(item_to_recommended1_item_map_cat1.items()), columns=['item_cde', 'recommended_item_cde_1'])

# Convert item_to_recommended_item_map_2 to a DataFrame
df_2 = pd.DataFrame(list(item_to_recommended2_item_map_cat1.items()), columns=['item_cde', 'recommended_item_cde_2'])

# Convert item_to_recommended_item_map_3 to a DataFrame
df_3 = pd.DataFrame(list(item_to_recommended3_item_map_cat1.items()), columns=['item_cde', 'recommended_item_cde_3'])

# Convert item_to_recommended_item_map_4 to a DataFrame
df_4 = pd.DataFrame(list(item_to_recommended4_item_map_cat1.items()), columns=['item_cde', 'recommended_item_cde_4'])

# Convert item_to_recommended_item_map_5 to a DataFrame
df_5 = pd.DataFrame(list(item_to_recommended5_item_map_cat1.items()), columns=['item_cde', 'recommended_item_cde_5'])

# Merge the first two DataFrames on 'item_cde'
merged_df = pd.merge(df_1, df_2, on='item_cde', how='outer')

# Merge the result with the third DataFrame on 'item_cde'
merged_df = pd.merge(merged_df, df_3, on='item_cde', how='outer')

# Merge the result with the fourth DataFrame on 'item_cde'
merged_df = pd.merge(merged_df, df_4, on='item_cde', how='outer')

# Merge the result with the fifth DataFrame on 'item_cde'
merged_df = pd.merge(merged_df, df_5, on='item_cde', how='outer')

# Fill missing values with NaN
merged_df.fillna('', inplace=True)

# Display the resulting DataFrame
print(merged_df)
# Out:
#    item_cde                             recommended_item_cde_1  \
# 0  10848206  [10169745, 10421097, 10049812, 10574148, 10093...
# 1  10880069  [10058192, 10036272, 10036273, 10036270, 10041...
# 2  10898537  [10058192, 10036272, 10036273, 10036270, 10041...
# 3  11085682  [10911713, 10735848, 10911699, 10735864, 10735...
# 4  11105343  [10058192, 10036272, 10036273, 10036270, 10041...
# 5  20034349  [10169745, 10421097, 10049812, 10574148, 10093...
# 6  20041652  [10169745, 10421097, 10049812, 10574148, 10093...
# 7  20078473  [10169745, 10421097, 10049812, 10574148, 10093...
#
#                               recommended_item_cde_2  \
# 0  [10943393, 10631239, 10477987, 11079423, 10762...
# 1  [10169745, 10421097, 10049812, 10574148, 10093...
# 2  [10169745, 10421097, 10049812, 10574148, 10093...
# 3  [10802527, 10298253, 10755118, 10755128, 10755...
# 4  [10169745, 10421097, 10049812, 10574148, 10093...
# 5  [10943393, 10631239, 10477987, 11079423, 10762...
# ...

# %%
# Apply a lambda function to each column to extract the first element
merged_df['recommended_item_cde_1'] = merged_df['recommended_item_cde_1'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else '')
merged_df['recommended_item_cde_2'] = merged_df['recommended_item_cde_2'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else '')
merged_df['recommended_item_cde_3'] = merged_df['recommended_item_cde_3'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else '')
merged_df['recommended_item_cde_4'] = merged_df['recommended_item_cde_4'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else '')
merged_df['recommended_item_cde_5'] = merged_df['recommended_item_cde_5'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else '')

# Display the resulting DataFrame
print(merged_df)
# Out:
#    item_cde recommended_item_cde_1 recommended_item_cde_2  \
# 0  10848206               10169745               10943393
# 1  10880069               10058192               10169745
# 2  10898537               10058192               10169745
# 3  11085682               10911713               10802527
# 4  11105343               10058192               10169745
# 5  20034349               10169745               10943393
# 6  20041652               10169745               11071078
# 7  20078473               10169745               11023420
#
#   recommended_item_cde_3 recommended_item_cde_4 recommended_item_cde_5
# 0               11023420               10943252               10343507
# 1               10645774               11023420               20064078
# 2               10645774               11023420               20064078
# 3               10169745               10728643               10058192
# 4               10645774               11023420               20064078
# ...

# %%
merged_df.to_csv('cat1_level_item_cde_to_reco_2.csv')

# %%
type(merged_df['item_cde'][0])
# Out:
# numpy.int64

# %%
# Iterate over the rows of product_result_100_freq
for index, row in product_result_100_freq.iterrows():
    # Get the item_cde from the current row
    item_cde = row['item_cde']
    
    # Check if the item_cde exists in merged_df
    if item_cde in merged_df['item_cde'].values:
        # Get the corresponding row from merged_df
        merged_row = merged_df[merged_df['item_cde'] == item_cde].iloc[0]
        
        # Copy values from merged_df to product_result_100_freq
        product_result_100_freq.at[index, 'Recommendation 1'] = merged_row['recommended_item_cde_1']
        product_result_100_freq.at[index, 'Recommendation 2'] = merged_row['recommended_item_cde_2']
        product_result_100_freq.at[index, 'Recommendation 3'] = merged_row['recommended_item_cde_3']
        product_result_100_freq.at[index, 'Recommendation 4'] = merged_row['recommended_item_cde_4']
        product_result_100_freq.at[index, 'Recommendation 5'] = merged_row['recommended_item_cde_5']

# Display the resulting DataFrame
print(product_result_100_freq)
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  item_cde  \
# 0              0.0           0.0         0.0  10012415
# 1              1.0           1.0         1.0  10012416
# 2              2.0           2.0         2.0  10012418
# 3              3.0           3.0         3.0  10012422
# 4              4.0           4.0         4.0  10012427
# ...            ...           ...         ...       ...
# 3769           NaN           NaN         NaN  20078238
# 3770           NaN           NaN         NaN  20078249
# 3771           NaN           NaN         NaN  20078274
# 3772           NaN           NaN         NaN  20078276
# 3773           NaN           NaN         NaN  20078277
#
#                                        item description Recommendation 1  \
# 0     8J8 FOAM CUP 8OZ SMALL INSULATED EPS HOT/COLD ...       10012427.0
# 1     12J16 FOAM CUP 12OZ J CUP INSULATED EPS HOT/CO...       10012724.0
# 2     10J10 CUP 10 OUNCE HOT OR COLD INSULATED FOAM ...       10012428.0
# ...

# %%
product_result_100_freq
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  item_cde  \
# 0              0.0           0.0         0.0  10012415
# 1              1.0           1.0         1.0  10012416
# 2              2.0           2.0         2.0  10012418
# 3              3.0           3.0         3.0  10012422
# 4              4.0           4.0         4.0  10012427
# ...            ...           ...         ...       ...
# 3769           NaN           NaN         NaN  20078238
# 3770           NaN           NaN         NaN  20078249
# 3771           NaN           NaN         NaN  20078274
# 3772           NaN           NaN         NaN  20078276
# 3773           NaN           NaN         NaN  20078277
#
#                                        item description Recommendation 1  \
# 0     8J8 FOAM CUP 8OZ SMALL INSULATED EPS HOT/COLD ...       10012427.0
# 1     12J16 FOAM CUP 12OZ J CUP INSULATED EPS HOT/CO...       10012724.0
# 2     10J10 CUP 10 OUNCE HOT OR COLD INSULATED FOAM ...       10012428.0
# ...
